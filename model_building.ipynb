# %%
import pandas as pd
df = pd.read_csv("input.csv")
df.head()
# Out:
#               location  total_sqft  bath  price  bhk
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2

# %%
# Converting text column into the numeric column using one hot encoding (pandas dummies method)
dummies = pd.get_dummies(df.location, drop_first=True)
dummies.head()
# Out:
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Block Hbr Layout  5th Phase JP Nagar  6th Phase JP Nagar  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    7th Phase JP Nagar  8th Phase JP Nagar  9th Phase JP Nagar  AECS Layout  \
# ...

# %%
# Appending the dummy columns to the main data frame
df = pd.concat([df, dummies], axis="columns")
df.head()
# Out:
#               location  total_sqft  bath  price  bhk  1st Phase JP Nagar  \
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4               False
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3               False
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3               False
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3               False
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
#
#    5th Phase JP Nagar  ...  Vishveshwarya Layout  Vishwapriya Layout  \
# ...

# %%
df = df.drop(["location"], axis="columns")
df.head()
# Out:
#    total_sqft  bath  price  bhk  1st Phase JP Nagar  \
# 0      2850.0   4.0  428.0    4               False
# 1      1630.0   3.0  194.0    3               False
# 2      1875.0   2.0  235.0    3               False
# 3      1200.0   2.0  130.0    3               False
# 4      1235.0   2.0  148.0    2               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  ...  Vishveshwarya Layout  \
# 0               False               False  ...                 False
# 1               False               False  ...                 False
# ...

# %%
# Creating dependent and independent data frames to feed to the model
X = df.drop(["price"], axis="columns")
X.head()
# Out:
#    total_sqft  bath  bhk  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0      2850.0   4.0    4               False                      False
# 1      1630.0   3.0    3               False                      False
# 2      1875.0   2.0    3               False                      False
# 3      1200.0   2.0    3               False                      False
# 4      1235.0   2.0    2               False                      False
#
#    2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    6th Phase JP Nagar  7th Phase JP Nagar  ...  Vishveshwarya Layout  \
# ...

# %%
y = df.price
y.head()
# Out:
# 0    428.0
# 1    194.0
# 2    235.0
# 3    130.0
# 4    148.0
# Name: price, dtype: float64

# %%
# Using K fold cross-validation, to train the Linear Regression Model
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import 
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
scores = cross_val_score(Li
